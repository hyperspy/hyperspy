# %% [markdown]
# # EDS doc

# %% [markdown]
# Examples in the EDS chapter

# %%
# %matplotlib qt4
import numpy as np
import hyperspy.api as hs
import matplotlib.pyplot as plt

# %% [markdown]
# ## Signal1D loading and parameters

# %%
from urllib.request import urlretrieve
url = 'http://cook.msm.cam.ac.uk//~hyperspy//EDS_tutorial//'
urlretrieve(url + 'Ni_superalloy_1pix.msa', 'Ni_superalloy_1pix.msa')
urlretrieve(url + 'Ni_superalloy_010.rpl', 'Ni_superalloy_010.rpl')
urlretrieve(url + 'Ni_superalloy_010.raw', 'Ni_superalloy_010.raw')
urlretrieve(url + 'Ni_superalloy_011.rpl', 'Ni_superalloy_011.rpl')
urlretrieve(url + 'Ni_superalloy_011.raw', 'Ni_superalloy_011.raw')
# Out:
# ('Ni_superalloy_011.raw', <http.client.HTTPMessage at 0x7fcc62188cc0>)

# %%
s = hs.load("Ni_superalloy_1pix.msa")
s
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# <Signal1D, title: Signal1D 2, dimensions: (|1024)>

# %%
si = hs.load("Ni_superalloy_010.rpl").as_signal1D(0)
si
# Out:
# Loading as Signal2D
# /home/to266/dev/hyperspy/hyperspy/signals.py:83: VisibleDeprecationWarning: The Signal2D class will be deprecated from version 1.0.0 and replaced with Signal2D
#   VisibleDeprecationWarning)
# /home/to266/dev/hyperspy/hyperspy/signal.py:3413: VisibleDeprecationWarning: The as_signal1D method will be deprecated from version 1.0.0 and replaced with as_signal1D
#   VisibleDeprecationWarning)
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# <Signal1D, title: , dimensions: (256, 224|1024)>

# %%
si4D = hs.load("Ni_superalloy_0*.rpl", stack=True)
si4D = si4D.as_signal1D(0)
si4D
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:83: VisibleDeprecationWarning: The Signal2D class will be deprecated from version 1.0.0 and replaced with Signal2D
#   VisibleDeprecationWarning)
# Loading individual files
# Loading as Signal2D
# Loading as Signal2D
#
# Individual files loaded correctly
#
# 	Title: doc_docstr_examples
# 	Signal type:
# 	Data dimensions: (1024, 2, 256, 224)
# 	Data representation: image
# 	Data type: uint8
# /home/to266/dev/hyperspy/hyperspy/signal.py:3413: VisibleDeprecationWarning: The as_signal1D method will be deprecated from version 1.0.0 and replaced with as_signal1D
#   VisibleDeprecationWarning)
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# <Signal1D, title: doc_docstr_examples, dimensions: (256, 224, 2|1024)>

# %%
s.set_signal_type("EDS_SEM")
s
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# <EDSSEMSpectrum, title: Signal1D 2, dimensions: (|1024)>

# %%
s = hs.load("Ni_superalloy_1pix.msa", signal_type="EDS_SEM")
s
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# <EDSSEMSpectrum, title: Signal1D 2, dimensions: (|1024)>

# %%
s = hs.load("Ni_superalloy_1pix.msa", signal_type="EDS_SEM")
s.metadata.Acquisition_instrument.SEM
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# ├── Detector
# │   └── EDS
# │       ├── azimuth_angle = 63.0
# │       ├── elevation_angle = 35.0
# │       ├── energy_resolution_MnKa = 130.0
# │       ├── live_time = 0.006855
# │       └── real_time = 0.0
# ├── beam_current = 0.0
# ├── beam_energy = 15.0
# └── tilt_stage = 38.0

# %%
s = hs.load("Ni_superalloy_1pix.msa", signal_type="EDS_SEM")
s.metadata.Acquisition_instrument.SEM.beam_energy = 30
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)

# %%
s = hs.load("Ni_superalloy_1pix.msa", signal_type="EDS_SEM")
s.set_microscope_parameters(beam_energy = 30)
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)

# %%
s = hs.load("Ni_superalloy_1pix.msa", signal_type="EDS_SEM")
s.set_microscope_parameters()
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)

# %%
si = hs.load("Ni_superalloy_010.rpl").as_signal1D(0)
# Out:
# Loading as Signal2D
# /home/to266/dev/hyperspy/hyperspy/signals.py:83: VisibleDeprecationWarning: The Signal2D class will be deprecated from version 1.0.0 and replaced with Signal2D
#   VisibleDeprecationWarning)
# /home/to266/dev/hyperspy/hyperspy/signal.py:3413: VisibleDeprecationWarning: The as_signal1D method will be deprecated from version 1.0.0 and replaced with as_signal1D
#   VisibleDeprecationWarning)
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)

# %%
si = hs.load("Ni_superalloy_010.rpl", signal_type="EDS_SEM").as_signal1D(0)
si.axes_manager[-1].name = 'E'
si.axes_manager['E'].units = 'keV'
si.axes_manager['E'].scale = 0.01
si.axes_manager['E'].offset = -0.1
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:83: VisibleDeprecationWarning: The Signal2D class will be deprecated from version 1.0.0 and replaced with Signal2D
#   VisibleDeprecationWarning)
# /home/to266/dev/hyperspy/hyperspy/signal.py:3413: VisibleDeprecationWarning: The as_signal1D method will be deprecated from version 1.0.0 and replaced with as_signal1D
#   VisibleDeprecationWarning)
# Loading as Signal2D
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)

# %%
si
# Out:
# <EDSSEMSpectrum, title: , dimensions: (256, 224|1024)>

# %%
# Load spectrum.msa which contains the parameters
s1pixel = hs.load("Ni_superalloy_1pix.msa", signal_type="EDS_TEM")
# Load spectrum_image.rpl which contains no parameters
si = hs.load("Ni_superalloy_010.rpl", signal_type="EDS_TEM").as_signal1D(0)
# Set all the properties of s1pixel to si
si.get_calibration_from(s1pixel)
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# /home/to266/dev/hyperspy/hyperspy/signals.py:83: VisibleDeprecationWarning: The Signal2D class will be deprecated from version 1.0.0 and replaced with Signal2D
#   VisibleDeprecationWarning)
# /home/to266/dev/hyperspy/hyperspy/signal.py:3413: VisibleDeprecationWarning: The as_signal1D method will be deprecated from version 1.0.0 and replaced with as_signal1D
#   VisibleDeprecationWarning)
# Loading as Signal2D

# %% [markdown]
# ## Describing the sample

# %%
s = hs.datasets.example_signals.EDS_TEM_Spectrum()
s.add_lines()
s.metadata.Sample.thickness = 100
s.metadata.Sample
# Out:
# Fe_Ka line added,
# Pt_La line added,
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# ├── description = 'FePt bimetallic nanoparticles'
# ├── elements = ['Fe', 'Pt']
# ├── thickness = 100
# └── xray_lines = ['Fe_Ka', 'Pt_La']

# %%
s = hs.datasets.example_signals.EDS_TEM_Spectrum()
s.set_elements(['Fe', 'Pt'])
s.add_elements(['Cu'])
s.metadata.Sample
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# ├── description = 'FePt bimetallic nanoparticles'
# └── elements = ['Cu', 'Fe', 'Pt']

# %%
s = hs.datasets.example_signals.EDS_TEM_Spectrum()
s.set_elements(['Fe', 'Pt'])
s.set_lines(['Fe_Ka', 'Pt_La'])
s.add_lines(['Fe_La'])
s.metadata.Sample
# Out:
# Fe_Ka line added,
# Pt_La line added,
# Fe_La line added,
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# ├── description = 'FePt bimetallic nanoparticles'
# ├── elements = ['Fe', 'Pt']
# └── xray_lines = ['Fe_Ka', 'Fe_La', 'Pt_La']

# %%
s = hs.datasets.example_signals.EDS_SEM_Spectrum()
s.metadata.Sample
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# ├── description = 'EDS-TM002 from BAM (www.webshop.bam.de)'
# └── elements = array(['Al', 'C', 'Cu', 'Mn', 'Zr'],
#       dtype='|S2')

# %%
s = hs.datasets.example_signals.EDS_SEM_Spectrum()
s.set_elements(['Al', 'Cu', 'Mn'])
s.set_microscope_parameters(beam_energy=30)
s.add_lines()
s.metadata.Sample
# Out:
# Al_Ka line added,
# Cu_Ka line added,
# Mn_Ka line added,
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# ├── description = 'EDS-TM002 from BAM (www.webshop.bam.de)'
# ├── elements = ['Al', 'Cu', 'Mn']
# └── xray_lines = ['Al_Ka', 'Cu_Ka', 'Mn_Ka']

# %%
s.set_microscope_parameters(beam_energy=10)
s.set_lines([])
s.metadata.Sample
# Out:
# Al_Ka line added,
# Cu_La line added,
# Mn_La line added,
# ├── description = 'EDS-TM002 from BAM (www.webshop.bam.de)'
# ├── elements = ['Al', 'Cu', 'Mn']
# └── xray_lines = ['Al_Ka', 'Cu_La', 'Mn_La']

# %%
s = hs.datasets.example_signals.EDS_SEM_Spectrum()
s.set_elements(['Mn'])
s.set_microscope_parameters(beam_energy=5)
s.add_lines(["Mn_Ka"])
# Out:
# Mn_Ka line added,
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# /home/to266/dev/hyperspy/hyperspy/_signals/eds.py:466: UserWarning: Mn_Ka is not in the data energy range.
#   warnings.warn("%s is not in the data energy range." % xray)

# %%
s = hs.datasets.example_signals.EDS_SEM_Spectrum()
s.set_elements(['Mn'])
s.set_microscope_parameters(beam_energy=5)
s.add_lines(['Mn_Ka'])
# Out:
# Mn_Ka line added,
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# /home/to266/dev/hyperspy/hyperspy/_signals/eds.py:466: UserWarning: Mn_Ka is not in the data energy range.
#   warnings.warn("%s is not in the data energy range." % xray)

# %%
s.plot(True)
# Out:
# Warning: Mn_Ka is not in the data energy range.

# %%
hs.material.elements.Fe.General_properties
# Out:
# ├── Z = 26
# ├── atomic_weight = 55.845
# └── name = iron

# %%
hs.material.elements.Fe.Physical_properties
# Out:
# └── density (g/cm^3) = 7.874

# %%
hs.material.elements.Fe.Atomic_properties.Xray_lines
# Out:
# ├── Ka
# │   ├── energy (keV) = 6.4039
# │   └── weight = 1.0
# ├── Kb
# │   ├── energy (keV) = 7.058
# │   └── weight = 0.1272
# ├── La
# │   ├── energy (keV) = 0.7045
# │   └── weight = 1.0
# ├── Lb3
# │   ├── energy (keV) = 0.7921
# │   └── weight = 0.02448
# ├── Ll
# │   ├── energy (keV) = 0.6152
# │   └── weight = 0.3086
# └── Ln
#     ├── energy (keV) = 0.6282
#     └── weight = 0.12525

# %% [markdown]
# ## Plotting

# %%
s = hs.datasets.example_signals.EDS_SEM_Spectrum()
s.plot()
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)

# %%
s = hs.datasets.example_signals.EDS_SEM_Spectrum()
s.add_elements(['C','Mn','Cu','Al','Zr'])
s.plot(True)
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)

# %%
s = hs.datasets.example_signals.EDS_SEM_Spectrum()
s.add_elements(['C','Mn','Cu','Al','Zr'])
s.plot(True, only_lines=['Ka','b'])
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)

# %% [markdown]
# ## Get lines intensity

# %%
from urllib.request import urlretrieve
url = 'http://cook.msm.cam.ac.uk//~hyperspy//EDS_tutorial//'
urlretrieve(url + 'core_shell.hdf5', 'core_shell.hdf5')
# Out:
# ('core_shell.hdf5', <http.client.HTTPMessage at 0x7fcc5ab55780>)

# %%
s = hs.load('core_shell.hdf5')
s.get_lines_intensity(['Fe_Ka'],plot_result=True)
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# /home/to266/dev/hyperspy/hyperspy/signals.py:126: VisibleDeprecationWarning: The Signal class will be deprecated from version 1.0.0 and replaced with BaseSignal
#   VisibleDeprecationWarning)
# [<Signal2D, title: X-ray line intensity of Core shell: Fe_Ka at 6.40 keV, dimensions: (|64, 64)>]

# %%
s = hs.load('core_shell.hdf5')
s.set_lines(['Fe_Ka', 'Pt_La'])
s.get_lines_intensity()
# Out:
# Fe_Ka line added,
# Pt_La line added,
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# /home/to266/dev/hyperspy/hyperspy/signals.py:126: VisibleDeprecationWarning: The Signal class will be deprecated from version 1.0.0 and replaced with BaseSignal
#   VisibleDeprecationWarning)
# [<Signal2D, title: X-ray line intensity of Core shell: Fe_Ka at 6.40 keV, dimensions: (|64, 64)>,
#  <Signal2D, title: X-ray line intensity of Core shell: Pt_La at 9.44 keV, dimensions: (|64, 64)>]

# %%
s = hs.datasets.example_signals.EDS_TEM_Spectrum()[5.:13.]
s.add_lines()
s.plot(integration_windows='auto')
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# /home/to266/dev/hyperspy/hyperspy/signal.py:1331: VisibleDeprecationWarning: Indexing the `Signal` class is deprecated and will be removed in Hyperspy 1.0. Please use `.isig` and/or `.inav` instead.
#   VisibleDeprecationWarning)
# Fe_Ka line added,
# Pt_La line added,
# /home/to266/anaconda3/lib/python3.5/site-packages/matplotlib/__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
#estimate_background_windows()
s = hs.datasets.example_signals.EDS_TEM_Spectrum()[5.:13.]
s.change_dtype('float')
s.add_lines()
bw = s.estimate_background_windows(line_width=[5.0, 2.0])
s.plot(background_windows=bw)
s.get_lines_intensity(background_windows=bw, plot_result=False)
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# /home/to266/dev/hyperspy/hyperspy/signal.py:1331: VisibleDeprecationWarning: Indexing the `Signal` class is deprecated and will be removed in Hyperspy 1.0. Please use `.isig` and/or `.inav` instead.
#   VisibleDeprecationWarning)
# Fe_Ka line added,
# Pt_La line added,
# /home/to266/anaconda3/lib/python3.5/site-packages/matplotlib/__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# [<EDSTEMSpectrum, title: X-ray line intensity of EDS TEM Signal1D: Fe_Ka at 6.40 keV, dimensions: (|1)>,
#  <EDSTEMSpectrum, title: X-ray line intensity of EDS TEM Signal1D: Pt_La at 9.44 keV, dimensions: (|1)>]

# %% [markdown]
# ## Quant

# %%
s = hs.datasets.example_signals.EDS_TEM_Spectrum()
s.change_dtype('float')
s.add_lines()
kfactors = [1.450226, 5.075602] #For Fe Ka and Pt La
bw = s.estimate_background_windows(line_width=[5.0, 2.0])
intensities = s.get_lines_intensity(background_windows=bw)
# Out:
# Fe_Ka line added,
# Pt_La line added,
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)

# %%
intensities
# Out:
# [<EDSTEMSpectrum, title: X-ray line intensity of EDS TEM Signal1D: Fe_Ka at 6.40 keV, dimensions: (|1)>,
#  <EDSTEMSpectrum, title: X-ray line intensity of EDS TEM Signal1D: Pt_La at 9.44 keV, dimensions: (|1)>]

# %%
intensities[0].axes_manager
# Out:
# <Axes manager, axes: (|<Scalar axis, size: 1>)>

# %%
intensities = hs.stack(intensities)
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)

# %%
intensities.split(axis=0)
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# [<EDSTEMSpectrum, title: Stack of X-ray line intensity of EDS TEM Signal1D: Fe_Ka at 6.40 keV, dimensions: (|1)>,
#  <EDSTEMSpectrum, title: Stack of X-ray line intensity of EDS TEM Signal1D: Fe_Ka at 6.40 keV, dimensions: (|1)>]

# %%
weight_percent = s.quantification(intensities, kfactors, plot_result=False)
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)

# %%
hs.material.weight_to_atomic(weight_percent)
# Out:
# /home/to266/dev/hyperspy/hyperspy/signals.py:54: VisibleDeprecationWarning: The Signal1D class will be deprecated from version 1.0.0 and replaced with Signal1D
#   VisibleDeprecationWarning)
# [<EDSTEMSpectrum, title: weight percent of Fe, dimensions: (|1)>,
#  <EDSTEMSpectrum, title: weight percent of Pt, dimensions: (|1)>]

# %% [markdown]
# ## Cleanup

# %%
# %%bash
#
# rm Ni_superalloy_1pix.msa Ni_superalloy_010.rpl Ni_superalloy_010.raw
# rm Ni_superalloy_011.rpl Ni_superalloy_011.raw
# rm core_shell.hdf5
