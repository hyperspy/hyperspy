# %%
import hyperspy.api as hs
# Out:
# WARNING:hyperspy.api:The ipywidgets GUI elements are not available, probably because the hyperspy_gui_ipywidgets package is not installed.
# WARNING:hyperspy.api:The traitsui GUI elements are not available, probably because the hyperspy_gui_traitsui package is not installed.

# %%
testimport = hs.load('hyperspy/tests/io/impulse_Data/Testexperimentlimited_Synchronized data.csv')

# %%
testimport
# Out:
# [<Signal1D, title: Temperature Measured (°C), dimensions: (|11113)>,
#  <Signal1D, title: MFC1 Measured (mln/min), dimensions: (|11113)>,
#  <Signal1D, title: MFC2 Measured (mln/min), dimensions: (|11113)>,
#  <Signal1D, title: MFC3 Measured (mln/min), dimensions: (|11113)>,
#  <Signal1D, title: MixValve (), dimensions: (|11113)>,
#  <Signal1D, title: Pin Measured (mbar), dimensions: (|11113)>,
#  <Signal1D, title: Pout Measured (mbar), dimensions: (|11113)>,
#  <Signal1D, title: Pnr (Calculated from Pin Pout) (mln/min), dimensions: (|11113)>,
#  <Signal1D, title: Fnr (mln/min), dimensions: (|11113)>,
#  <Signal1D, title: % Gas1 Measured (%), dimensions: (|11113)>,
#  <Signal1D, title: % Gas2 Measured (%), dimensions: (|11113)>,
#  <Signal1D, title: % Gas3 Measured (%), dimensions: (|11113)>,
#  <Signal1D, title: PumpRotation (Hz), dimensions: (|11113)>,
#  <Signal1D, title: Pvac (mbar), dimensions: (|11113)>,
#  <Signal1D, title: Channel#1 (mbar), dimensions: (|11113)>,
#  <Signal1D, title: Channel#2 (mbar), dimensions: (|11113)>]

# %%
testimport[1].plot()
